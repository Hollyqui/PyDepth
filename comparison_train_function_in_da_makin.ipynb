# %%
def comparison_train_function(Left_value, right_values, area, left_image, right_image, x, y, i, left_square, right_square):

    count=0
    matrix = []
    for i in range(480):
        matrix.append([])
        for j in range(640):
            matrix[i].append(count)
            count+=1


    matrix = np.array(matrix)
    #print(matrix)

    i = 5 #vertical sa_
    j = 4 #horizontal
    square_size = 4
    left_square = matrix[i-square_size:i+square_size+1, j-square_size:j+square_size+1]
    #print(left_square)
    
   
    left_image = np.random.rand(y, x)
    right_image = np.random.rand(j, i)
    square_size=5
    sa_height=[j-3:j+4] #3 up ad 3 down
    sa_width=[i-10:i+11] #10 left and 10 right
    
    left_square = matrix[i-square_size:i+square_size+1, j-square_size:j+square_size+1]
    
    for y in left_image: #vertical
        for x in left_image: #up until here: for every pixel on the left image #horizontal
            #now: go through every element of the search area
            for j in sa_height:
                for i in sa_width: #for every pixel of the search area that corresponds to every pixel in left image
                    #store pixel values (square size) in matrix form, located at left and right image at (x, y) and (i, j) respectively
                    #calculate the area of overlap of 2 squares 
                      
                    if x > i and j > y
                    area=(((i+square_size)-(x-square_size))*((j-square_size)-(y+square_size))
                    if x<i and j>y
                    area=(((x+square_size)-(i-square_size))*((y+square_size)-(j-square_size)))
                    if x>i and j<y
                    area=(((i+square_size)-(x-square_size))*((j+square_size)-(y-square_size)))
                    if x<i and j<y
                    area=(((x+square_size)-(i-square_size))*((j+square_size)-(y-square_size)))
    
    #calculate how many pixels from the right corresponds to pixels on the left.
    
#     left_squares = []
#     right_squares = []
#     overlap = []
    for x in left_image: #do the below thingy not only for 1 pixel, but for every single pixel on the left image
          for y in left_image:
            Left_value = list(left_square.getdata()) #left_value function defined as a list of pixel values of left_square, which is defined as all pixels in a square_size on the left image
            # left_value = left_image[x-square_size:x+square_size, y-square_size:y+square_size]    
              #now: for each left value you need to find all the right values, and for each right value a compare one
            Right_value = list(right_square.getdata()) #it gives you matrices of pixel values for all search area
                for i in Right_value#for every one of the matrices that right_value produces (that cover the entire search area)
                area(Left_value, Right_value)
                print("The left image has pixel values ",Left_values, "for coordinates (", x, y, ") which correspond to coordinates (", i, j, ") (within the search area) on the right image; these have pixel values", Right_values, ". The % of picture overlap is ", area)
